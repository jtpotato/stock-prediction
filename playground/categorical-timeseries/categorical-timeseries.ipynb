# %%
import pandas as pd

df = pd.read_csv('data.csv')

df
# Out:
#     index  value  category1  category2
# 0       1      1          1          0
# 1       2      2          1          0
# 2       3      3          1          0
# 3       4      4          1          0
# 4       5      5          1          0
# 5       6      6          1          0
# 6       7      7          1          0
# 7       8      8          1          0
# 8       9      9          1          0
# 9      10     10          1          0
# 10     11     11          1          0
# 11     12     12          1          0
# 12     13     13          1          0
# 13     14     14          1          0
# 14     15     15          1          0
# 15     16     16          1          0
# 16      1     16          0          1
# 17      2     15          0          1
# 18      3     14          0          1
# 19      4     13          0          1
# 20      5     12          0          1
# 21      6     11          0          1
# 22      7     10          0          1
# 23      8      9          0          1
# 24      9      8          0          1
# 25     10      7          0          1
# 26     11      6          0          1
# 27     12      5          0          1
# 28     13      4          0          1
# 29     14      3          0          1
# 30     15      2          0          1
# 31     16      1          0          1

# %%
import matplotlib.pyplot as plt

category1 = df[df['category1'] == 1]
category2 = df[df['category2'] == 1]

plt.plot(category1['index'], category1['value'], color='r')
plt.plot(category2['index'], category2['value'], color='b')

# %%
# train-test split for time series
train_size = int(len(df) * 0.67)
test_size = len(df) - train_size
train, test = df[:train_size], df[train_size:]

train
# Out:
#     index  value  category1  category2
# 0       1      1          1          0
# 1       2      2          1          0
# 2       3      3          1          0
# 3       4      4          1          0
# 4       5      5          1          0
# 5       6      6          1          0
# 6       7      7          1          0
# 7       8      8          1          0
# 8       9      9          1          0
# 9      10     10          1          0
# 10     11     11          1          0
# 11     12     12          1          0
# 12     13     13          1          0
# 13     14     14          1          0
# 14     15     15          1          0
# 15     16     16          1          0
# 16      1     16          0          1
# 17      2     15          0          1
# 18      3     14          0          1
# 19      4     13          0          1
# 20      5     12          0          1
