# %%
import pandas as pd

# %%
stock_list = pd.read_csv("stocks.tsv", sep="\t").sample(n=40, random_state=2024)

stocks = stock_list["STOCK"]

stocks
# Out:
# 178    VAP
# 21     ARG
# 193    WPL
# 147    RRL
# 98     LLC
# 68     ELD
# 101    MCY
# 81     HLS
# 192    WOW
# 30     BIN
# 1      AAA
# 164    STO
# 37     BWP
# 161    SNZ
# 46     CHN
# 88     ILU
# 113    NAB
# 76     GMG
# 40     CBA
# 33     BOQ
# 188    WBC
# 15     ANZ
# 38     BXB
# 108    MLT
# 0      A2M
# 140    QBE
# 112    MTS
# 195    WTC
# 19     APX
# 80     GXY
# 162    SOL
# 49     CLW
# 167    SUN
# 77     GNE
# 130    PDL
# 79     GPT
# 44     CGF
# 125    ORG
# 34     BPT
# 70     EVN
# Name: STOCK, dtype: object

# %%
DAYS_LAGGED = 5
COLUMNS = ["Close", "Volume"]

# %%
training_data = pd.DataFrame()

for stock in stocks:
  stock_dataframe = pd.read_csv(f"tickers/{stock}.csv")
  for i in range(DAYS_LAGGED):
    for column in COLUMNS:
      stock_dataframe[f"{column}-{i + 1}"] = stock_dataframe[column].shift(i + 1)
      stock_dataframe = stock_dataframe.dropna()
  
  training_data = pd.concat([training_data, stock_dataframe], ignore_index=True)

training_data
# Out:
# /var/folders/4f/zhjjvgx16sl18qcqxczjhqhm0000gn/T/ipykernel_72257/2552339951.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   training_data = pd.concat([training_data, stock_dataframe], ignore_index=True)
# /var/folders/4f/zhjjvgx16sl18qcqxczjhqhm0000gn/T/ipykernel_72257/2552339951.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   training_data = pd.concat([training_data, stock_dataframe], ignore_index=True)
# ...

# %%
training_data = training_data.drop(["Volume"], axis="columns")

# %%
training_data.to_csv("cleaned_data.csv", index=False)
